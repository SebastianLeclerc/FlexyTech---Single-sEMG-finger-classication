# %%
import pandas as pd
import numpy as np
from combine_data import combine_data
from data_processing import ADC_to_v,format_timestamps
import librosa
import os,shutil
import matplotlib.pyplot as plt
import scipy
from scipy import signal

# %%
raw_data,labels,time_stamps = combine_data('./../data/al_data')
labels -=1
# Out:
# C:\Users\Nazem\OneDrive\Documents\GitHub\emg_DVA435_CDT406\src\combine_data.py:19: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   data = np.array(data)
# C:\Users\Nazem\OneDrive\Documents\GitHub\emg_DVA435_CDT406\src\combine_data.py:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   time_stamps = np.array(time_stamps)

# %%
voltage_values = []
time = []
for i in raw_data:
    voltage_values.append(ADC_to_v(i))
for i in time_stamps:
    time.append(format_timestamps(i))

# %%
n_sample = 100

# %%
plt.plot(time[n_sample],voltage_values[n_sample])
plt.grid()

# %%
from librosa import display

# %%
from scipy.signal import butter, lfilter


def butter_bandpass(lowcut, highcut, fs, order=5):
    return butter(order, [lowcut, highcut], fs=fs, btype='band')

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

def filter(voltage_values,low_cut=1,high_cut=55,fs = 1e3,):
    '''
    band pass filter based on the scipy butter bandpass, allowing frequency between low cut and high cut to pass through.
    input : np.array of the data voltage values.
    low_cut : lowest frequency defaults at 1
    high cut : highest frequency in the band filter defaults at 55.
    '''
    return butter_bandpass_filter(voltage_values,lowcut=low_cut,highcut=high_cut,fs = fs)

# %%
from scipy.signal import butter, lfilter


def butter_bandpass(lowcut, highcut, fs, order=5):
    return butter(order, [lowcut, highcut], fs=fs, btype='band')

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
from scipy.fft import fft, fftfreq
fft_vals = abs(fft(voltage_values[n_sample],n=16))
fft_vals
# Out:
# array([0.12175798, 0.00612011, 0.0020536 , 0.00159875, 0.00043964,
#        0.00069025, 0.00176762, 0.00286385, 0.00043964, 0.00286385,
#        0.00176762, 0.00069025, 0.00043964, 0.00159875, 0.0020536 ,
#        0.00612011], dtype=float32)

# %%
plt.plot(librosa.fft_frequencies(sr=1000, n_fft=16),fft_vals[:len(fft_vals)//2+1])

# %%
filtered = butter_bandpass_filter(voltage_values[n_sample],1,40,1000)

# %%
plt.plot(filtered)
plt.grid()

# %%
from scipy.integrate import cumtrapz

# %%
plt.plot((filtered))
plt.plot(1/np.pi * cumtrapz(filtered))

# %%
from feature_extraction import *

# %%
filtered_values = []
for i in voltage_values:
    filtered_values.append(filter(i,high_cut=60))

# %%
plt.subplot(1,2,1)
plt.title(f"{labels[n_sample]} filtered")
plt.plot(filtered)
plt.grid()
plt.subplot(1,2,2)
plt.title(f"{labels[n_sample]} raw")
plt.plot(voltage_values[n_sample])
plt.grid()

# %%
features = [root_mean_squared,iemg,mean_absolute_value,variance,wave_form_length,mean,median,skewness,kurt,zero_crossing_rate]
df = extract_features(raw_data,label = labels,features_no=3,overlapping_percentage=0.25,features_funcs=features)
# Out:
#                                 root_mean_squared  \
# 0     [3379.2437, 3411.863, 3406.6392, 3409.9668]
# 1     [3391.812, 3408.4663, 3412.9492, 3413.2078]
# 176  [-0.89739156, -0.7050731, -0.8947892, -0.7823405]  [0.0, 0.0, 0.0, 0.0]
# 177  [-0.026262522, -0.5588262, -0.80653644, -0.492...  [0.0, 0.0, 0.0, 0.0]
#
#      labels
# 0         0
# 1         1
# 2         2
# 3         0
# 4         1
# ..      ...
# 173       1
# 174       2
# 175       0
# 176       1
# 177       2
#
# [178 rows x 11 columns]
# C:\Users\Nazem\OneDrive\Documents\GitHub\emg_DVA435_CDT406\src\feature_extraction.py:80: UserWarning: needs fixing the results might be wrong.
#   warnings.warn("needs fixing the results might be wrong.")

# %%
df.columns
# Out:
# Index(['root_mean_squared1', 'root_mean_squared2', 'root_mean_squared3',
#        'root_mean_squared4', 'iemg1', 'iemg2', 'iemg3', 'iemg4',
#        'mean_absolute_value1', 'mean_absolute_value2', 'mean_absolute_value3',
#        'mean_absolute_value4', 'variance1', 'variance2', 'variance3',
#        'variance4', 'wave_form_length1', 'wave_form_length2',
#        'wave_form_length3', 'wave_form_length4', 'mean1', 'mean2', 'mean3',
#        'mean4', 'median1', 'median2', 'median3', 'median4', 'skewness1',
#        'skewness2', 'skewness3', 'skewness4', 'kurt1', 'kurt2', 'kurt3',
#        'kurt4', 'zero_crossing_rate1', 'zero_crossing_rate2',
#        'zero_crossing_rate3', 'zero_crossing_rate4', 'label'],
#       dtype='object')

# %%
import seaborn as sns
from sklearn.decomposition import PCA

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import minmax_scale,normalize,StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras import Sequential

# %%
X,y = df.drop('label',axis = 1),df['label']
X_scaled =minmax_scale(X)

# %%
pca = PCA(n_components=7)
pca.fit(X_scaled)
components = pca.transform(X_scaled)

# %%
x_train,x_test,y_train,y_test = train_test_split(components,y,train_size=0.7)
x_train.shape
# Out:
# (124, 7)

# %%
# parameter 1 
encoding_dim = 100
# ncol # without the label column
ncol = x_train.shape[1:][0]
ncol
# Out:
# 7

# %%
model = Sequential()
model.add(keras.layers.Input(shape=x_train.shape[1:]))
model.add(keras.layers.Dense(40))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(10))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(5))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(3,activation = 'softmax'))

# %%
loss_fn = loss_fn = keras.losses.SparseCategoricalCrossentropy()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),loss=loss_fn,metrics = ['accuracy'],)

# %%
model.summary()
# Out:
# Model: "sequential_52"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_172 (Dense)           (None, 40)                320
#
#  dropout_58 (Dropout)        (None, 40)                0
#
#  dense_173 (Dense)           (None, 10)                410
#
#  dropout_59 (Dropout)        (None, 10)                0
#
#  dense_174 (Dense)           (None, 5)                 55
#
#  dropout_60 (Dropout)        (None, 5)                 0
#
#  dense_175 (Dense)           (None, 3)                 18
#
# =================================================================
# Total params: 803
# Trainable params: 803
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x = x_train,y=y_train,validation_split=0.3,epochs=200)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 300ms/step - loss: 1.1170 - accuracy: 0.3605 - val_loss: 1.1398 - val_accuracy: 0.3421
# Epoch 2/200
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0910 - accuracy: 0.4535 - val_loss: 1.1351 - val_accuracy: 0.3421
# Epoch 3/200
# 3/3 [==============================] - 0s 76ms/step - loss: 1.
200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7788 - accuracy: 0.6163 - val_loss: 1.0916 - val_accuracy: 0.4737
# Epoch 62/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8270 - accuracy: 0.6395 - val_loss: 1.0953 - val_accuracy: 0.4737
# Epoch 63/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8578 - accuracy: 0.5930 - val_loss: 1.0983 - val_accuracy: 0.4737
# Epoch 64/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8296 - accuracy: 0.6512 - val_loss: 1.1003 - val_accuracy: 0.4737
# Epoch 65/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7871 - accuracy: 0.5814 - val_loss: 1.1028 - val_accuracy: 0.4737
# Epoch 66/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8801 - accuracy: 0.5814 - val_loss: 1.1060 - val_accuracy: 0.4737
# Epoch 67/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8381 - accuracy: 0.6163 - val_loss: 1.1088 - val_accuracy: 0.4737
# Epoch 68/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.8373 - accuracy: 0.6279 - val_loss: 1.1145 - val_accuracy: 0.4737
# Epoch 69/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7692 - accuracy: 0.6860 - val_loss: 1.1206 - val_accuracy: 0.4737
# Epoch 70/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7844 - accuracy: 0.6512 - val_loss: 1.1232 - val_accuracy: 0.5000
# Epoch 71/200
# 3/3 [==============================] - 0s 69ms/step - loss: 0.7984 - accuracy: 0.6279 - val_loss: 1.1277 - val_accuracy: 0.5000
# Epoch 72/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7905 - accuracy: 0.6395 - val_loss: 1.1332 - val_accuracy: 0.5000
# Epoch 73/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.8110 - accuracy: 0.6279 - val_loss: 1.1366 - val_accuracy: 0.5000
# Epoch 74/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.7697 - accuracy: 0.6628 - val_loss: 1.1401 - val_accuracy: 0.5000
# Epoch 75/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7852 - accuracy: 0.5930 - val_loss: 1.1441 - val_accuracy: 0.5000
# Epoch 76/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7723 - accuracy: 0.6628 - val_loss: 1.1470 - val_accuracy: 0.5000
# Epoch 77/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7975 - accuracy: 0.6512 - val_loss: 1.1489 - val_accuracy: 0.5000
# Epoch 78/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.7578 - accuracy: 0.6395 - val_loss: 1.1523 - val_accuracy: 0.5000
# Epoch 79/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7477 - accuracy: 0.6512 - val_loss: 1.1551 - val_accuracy: 0.5000
# Epoch 80/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7751 - accuracy: 0.6628 - val_loss: 1.1611 - val_accuracy: 0.5000
# Epoch 81/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.8046 - accuracy: 0.6628 - val_loss: 1.1645 - val_accuracy: 0.5000
# Epoch 82/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7470 - accuracy: 0.6279 - val_loss: 1.1685 - val_accuracy: 0.5000
# Epoch 83/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7432 - accuracy: 0.5930 - val_loss: 1.1736 - val_accuracy: 0.5000
# Epoch 84/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7890 - accuracy: 0.6279 - val_loss: 1.1792 - val_accuracy: 0.5000
# Epoch 85/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7667 - accuracy: 0.6047 - val_loss: 1.1825 - val_accuracy: 0.5000
# Epoch 86/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7937 - accuracy: 0.6163 - val_loss: 1.1874 - val_accuracy: 0.5000
# Epoch 87/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.8240 - accuracy: 0.6163 - val_loss: 1.1955 - val_accuracy: 0.5263
# Epoch 88/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7879 - accuracy: 0.6512 - val_loss: 1.2035 - val_accuracy: 0.5263
# Epoch 89/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7409 - accuracy: 0.6163 - val_loss: 1.2059 - val_accuracy: 0.5000
# Epoch 90/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7345 - accuracy: 0.6977 - val_loss: 1.2083 - val_accuracy: 0.5000
# Epoch 91/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.
200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6856 - accuracy: 0.6744 - val_loss: 1.3162 - val_accuracy: 0.4737
# Epoch 121/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7665 - accuracy: 0.6279 - val_loss: 1.3200 - val_accuracy: 0.4737
# Epoch 122/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7195 - accuracy: 0.6047 - val_loss: 1.3232 - val_accuracy: 0.4211
# Epoch 123/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7451 - accuracy: 0.6744 - val_loss: 1.3281 - val_accuracy: 0.4474
# Epoch 124/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7865 - accuracy: 0.6395 - val_loss: 1.3313 - val_accuracy: 0.5000
# Epoch 125/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7273 - accuracy: 0.6860 - val_loss: 1.3320 - val_accuracy: 0.5000
# Epoch 126/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7348 - accuracy: 0.6512 - val_loss: 1.3323 - val_accuracy: 0.5000
# Epoch 127/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6785 - accuracy: 0.6977 - val_loss: 1.3350 - val_accuracy: 0.5000
# Epoch 128/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7049 - accuracy: 0.6744 - val_loss: 1.3370 - val_accuracy: 0.5000
# Epoch 129/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7714 - accuracy: 0.5930 - val_loss: 1.3395 - val_accuracy: 0.5000
# Epoch 130/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7224 - accuracy: 0.6512 - val_loss: 1.3432 - val_accuracy: 0.5000
# Epoch 131/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7372 - accuracy: 0.6512 - val_loss: 1.3456 - val_accuracy: 0.5000
# Epoch 132/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.7570 - accuracy: 0.6744 - val_loss: 1.3496 - val_accuracy: 0.5000
# Epoch 133/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6939 - accuracy: 0.6744 - val_loss: 1.3515 - val_accuracy: 0.5000
# Epoch 134/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7243 - accuracy: 0.6512 - val_loss: 1.3549 - val_accuracy: 0.5000
# Epoch 135/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7509 - accuracy: 0.6512 - val_loss: 1.3607 - val_accuracy: 0.5000
# Epoch 136/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.7174 - accuracy: 0.6512 - val_loss: 1.3655 - val_accuracy: 0.5000
# Epoch 137/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7682 - accuracy: 0.5698 - val_loss: 1.3693 - val_accuracy: 0.5000
# Epoch 138/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7091 - accuracy: 0.6628 - val_loss: 1.3676 - val_accuracy: 0.5000
# Epoch 139/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7539 - accuracy: 0.6395 - val_loss: 1.3685 - val_accuracy: 0.5000
# Epoch 140/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7245 - accuracy: 0.6163 - val_loss: 1.3675 - val_accuracy: 0.5000
# Epoch 141/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7443 - accuracy: 0.6163 - val_loss: 1.3659 - val_accuracy: 0.4737
# Epoch 142/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.7362 - accuracy: 0.6744 - val_loss: 1.3626 - val_accuracy: 0.4737
# Epoch 143/200
# 3/3 [==============================] - 0s 25ms/step - loss: 0.7142 - accuracy: 0.6395 - val_loss: 1.3625 - val_accuracy: 0.4737
# Epoch 144/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7503 - accuracy: 0.6279 - val_loss: 1.3645 - val_accuracy: 0.4737
# Epoch 145/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7420 - accuracy: 0.6163 - val_loss: 1.3688 - val_accuracy: 0.4737
# Epoch 146/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7067 - accuracy: 0.6279 - val_loss: 1.3726 - val_accuracy: 0.4737
# Epoch 147/200
# 3/3 [==============================] - 0s 23ms/step - loss: 0.6856 - accuracy: 0.7093 - val_loss: 1.3755 - val_accuracy: 0.4737
# Epoch 148/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6950 - accuracy: 0.6977 - val_loss: 1.3800 - val_accuracy: 0.4737
# Epoch 149/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.
200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7182 - accuracy: 0.6628 - val_loss: 1.4724 - val_accuracy: 0.4737
# Epoch 180/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7402 - accuracy: 0.6977 - val_loss: 1.4659 - val_accuracy: 0.4737
# Epoch 181/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7434 - accuracy: 0.6744 - val_loss: 1.4598 - val_accuracy: 0.4737
# Epoch 182/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7683 - accuracy: 0.6860 - val_loss: 1.4618 - val_accuracy: 0.4737
# Epoch 183/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7124 - accuracy: 0.6977 - val_loss: 1.4665 - val_accuracy: 0.4737
# Epoch 184/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7431 - accuracy: 0.6628 - val_loss: 1.4734 - val_accuracy: 0.4737
# Epoch 185/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7519 - accuracy: 0.6860 - val_loss: 1.4781 - val_accuracy: 0.4737
# Epoch 186/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6571 - accuracy: 0.7209 - val_loss: 1.4794 - val_accuracy: 0.4474
# Epoch 187/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7212 - accuracy: 0.6628 - val_loss: 1.4806 - val_accuracy: 0.4211
# Epoch 188/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7207 - accuracy: 0.6512 - val_loss: 1.4798 - val_accuracy: 0.4211
# Epoch 189/200
# 3/3 [==============================] - 0s 20ms/step - loss: 0.6965 - accuracy: 0.6744 - val_loss: 1.4793 - val_accuracy: 0.4211
# Epoch 190/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7431 - accuracy: 0.6395 - val_loss: 1.4793 - val_accuracy: 0.4211
# Epoch 191/200
# 3/3 [==============================] - 0s 21ms/step - loss: 0.7040 - accuracy: 0.6512 - val_loss: 1.4766 - val_accuracy: 0.4211
# Epoch 192/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.6908 - accuracy: 0.6860 - val_loss: 1.4781 - val_accuracy: 0.4211
# Epoch 193/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.8026 - accuracy: 0.6512 - val_loss: 1.4783 - val_accuracy: 0.4211
# Epoch 194/200
# 3/3 [==============================] - 0s 19ms/step - loss: 0.7493 - accuracy: 0.6512 - val_loss: 1.4717 - val_accuracy: 0.4211
# Epoch 195/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7196 - accuracy: 0.6977 - val_loss: 1.4685 - val_accuracy: 0.4211
# Epoch 196/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6872 - accuracy: 0.6628 - val_loss: 1.4645 - val_accuracy: 0.4737
# Epoch 197/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.7235 - accuracy: 0.6628 - val_loss: 1.4668 - val_accuracy: 0.4737
# Epoch 198/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.7811 - accuracy: 0.6628 - val_loss: 1.4713 - val_accuracy: 0.4737
# Epoch 199/200
# 3/3 [==============================] - 0s 17ms/step - loss: 0.7524 - accuracy: 0.6744 - val_loss: 1.4785 - val_accuracy: 0.4737
# Epoch 200/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.7314 - accuracy: 0.6628 - val_loss: 1.4876 - val_accuracy: 0.4737

# %%
from sklearn.svm import SVC

# %%
svm = SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
predictions_ann = np.argmax(model.predict(x_test),axis=1)
predictions_svc = svm.predict(x_test)
from sklearn.metrics import classification_report
print(classification_report(y_true = y_test,y_pred=predictions_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.58      0.54        19
#            1       0.47      0.41      0.44        17
#            2       0.82      0.78      0.80        18
#
#     accuracy                           0.59        54
#    macro avg       0.60      0.59      0.59        54
# weighted avg       0.60      0.59      0.59        54

# %%
import inspect

# %%
print(inspect.getsource(ADC_to_v))
# Out:
# def ADC_to_v(sample:np.array,max_voltage = 1.8,ADC_resolution = 4095,resting_voltage=1.5):
#     return sample * (max_voltage)/ADC_resolution - 1.5
